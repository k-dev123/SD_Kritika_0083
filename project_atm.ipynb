# %% [markdown]
# <a href="https://colab.research.google.com/github/k-dev123/SD_Kritika_0083/blob/main/project_atm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def wid():
    ENTER_AMOUNT=int(input("ENTER AMOUNT"))
    print("VALIDATING AMOUNT")
    if D["balance"]> ENTER_AMOUNT:
        print("SUFFICIENT BALANCE")
        print("AMOUNT DEBITED:",  ENTER_AMOUNT)
        print("WITHDRAWL SUCCESSFUL")
        print("AMOUNT LEFT:",D["balance"]- ENTER_AMOUNT)
        print(" CARD EJECTED")
    else:
        print("INSUFFICIENT BALANCE")
        print(" CARD EJECTED")
def dep():
    AMOUNT=int(input("ENTER AMOUNT TO BE DEPOSITED:"))
    print("CASH DETECTED")
    print("CASH DEPOSITED SUCCESSFULLY!!!")
    print("AMOUNT:",AMOUNT,"IS CREDITED TO YOUR ACCOUNT")
    print(" CARD EJECTED")
def inq():
    print("BALANCE IN YOUR ACCOUNT:",D["balance"])
    print(" CARD EJECTED")
D={"acc_no":45457532,"balance":50000,"pin-no":45663}
print("INSERT CARD")
CARD_NO=int(input("ENTER CARD NO."))
PIN_NO=int(input("ENTER PIN NO."))
print(" SERVICES:")
print("WITHDRAWL")
print("DEPOSIT")
print("BALANCE ENQUIRY")
print("_EXIT")
SERVICES=input("ENTER SERVICES")
if SERVICES=="WITHDRAWL":
    wid()

elif SERVICES=="DEPOSIT":
    dep()

elif SERVICES=="BALANCE INQUIRY":
    inq()
elif SERVICES=="EXIT":
    print("CARD EJECTED")
    print("THANK YOU!!")
else:
    print("INVALID CHOICE")
    print("EJECT CARD")
# Out:
# INSERT CARD
# ENTER CARD NO.45457532
# ENTER PIN NO.45663
#  SERVICES:
# WITHDRAWL
# DEPOSIT
# BALANCE ENQUIRY
# _EXIT
# ENTER SERVICESWITHDRAWL
# ENTER AMOUNT500
# VALIDATING AMOUNT
# SUFFICIENT BALANCE
# AMOUNT DEBITED: 500
# WITHDRAWL SUCCESSFUL
# AMOUNT LEFT: 49500
#  CARD EJECTED
