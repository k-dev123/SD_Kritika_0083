# %% [markdown]
# <a href="https://colab.research.google.com/github/k-dev123/SD_Kritika_0083/blob/main/generator_fun_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fib(n):
  a=1
  b=0
  t=0
  for i in range(0,n):
    if i==0:
      print(0)
    else:
      t=a+b
      print(t)
      a=b
      b=t
n=int(input("enter a no."))
fib(n)
# Out:
# enter a no.5
# 0
# 1
# 1
# 2
# 3

# %%
def test_fib(n):
  a,b=0,1
  for i in range(n):
    yield a
    a,b=b,a+b

# %%
s="sudh"
for i in s:
  print(i)
# Out:
# s
# u
# d
# h

# %%
s1=iter(s)

# %%
type(s1)
# Out:
# str_ascii_iterator

# %%
next(s1)
# Out:
# 'u'

# %%
next(s1)
# Out:
# 'd'

# %%
next(s1)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_790/1205934168.py in <cell line: 0>()
# ----> 1 next(s1)
#
# StopIteration:

# %%
iter(45)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_790/3186544426.py in <cell line: 0>()
# ----> 1 iter(45)
#
# TypeError: 'int' object is not iterable

# %%
def count_test(n):
  count=1
  while count<=n:
    yield count
    count+=1
count_test(3)
# Out:
# <generator object count_test at 0x7858b5eb1780>

# %%
for i in count_test(5):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
