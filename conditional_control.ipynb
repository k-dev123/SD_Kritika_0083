# %% [markdown]
# <a href="https://colab.research.google.com/github/k-dev123/SD_Kritika_0083/blob/main/conditional_control.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=10
if x>5:
  print("x is greater than 5")
# Out:
# x is greater than 5

# %%
x=3
if x%2==0:
  print("true")
else:
  print("false")
# Out:
# false

# %%
#name=input("enter user name: ")
# batch=input("enter ur batch")
# rollno=int(input("enter ur rollno"))
# course=input("enter ur course")
for i in range(3):
  s=input("enter sub")
  m=int(input("enter marks"))
  if m>=80:
    print("grade a")
  elif m>=50 and m<80:
    print("grade b")
  else:
    print("grade c")
print("end")
# Out:
# enter user name: er
# enter subd
# enter marks34
# grade c
# enter subhindi
# enter marks80
# grade a
# enter submaths
# enter marks50
# grade b
# end
