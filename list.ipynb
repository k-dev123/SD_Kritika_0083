# %% [markdown]
# <a href="https://colab.research.google.com/github/k-dev123/SD_Kritika_0083/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=[1,2,3,4]
name[0]
# Out:
# 1

# %%
name[1]
# Out:
# 2

# %%
name[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_2403/4027671959.py in <cell line: 0>()
# ----> 1 name[4]
#
# IndexError: list index out of range

# %%
type(name)
# Out:
# list

# %%
l=[0,"items",2.9,89,True]
l[0:5:2]
# Out:
# [0, 2.9, True]

# %%
l=[1,345,45,"sudh",True,5+7j,345.456]
l[5].real
# Out:
# 5.0

# %%
l[::2]
# Out:
# [1, 45, True, 345.456]

# %%
l[5].imag
# Out:
# 7.0

# %%
n="24455"
n[::-1]
# Out:
# '55442'

# %%
s=int(n)

# %%
s
# Out:
# 24455

# %%
l[1:6:-2]
# Out:
# []

# %%
l[-1:-7:-6]
# Out:
# [345.456]

# %%
l[-1:-7:-5]
# Out:
# [345.456, 345]

# %%
l[-1:-8:-6]
# Out:
# [345.456, 1]

# %%
l.append("new")

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 'new']

# %%
l.pop()
# Out:
# 345.456

# %%
s="qwekgkojgkknsfl"
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1080/1406954541.py in <cell line: 0>()
#       1 s="qwekgkojgkknsfl"
# ----> 2 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
l.append(s)

# %%
l.pop()
# Out:
# True

# %%
l.append(True)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, True]

# %%
list(s)+l
# Out:
# ['q',
#  'w',
#  'e',
#  'k',
#  'g',
#  'k',
#  'o',
#  'j',
#  'g',
#  'k',
#  'k',
#  'n',
#  's',
#  'f',
#  'l',
#  1,
#  345,
#  45,
#  'sudh',
#  True,
#  True]

# %%
l1=[2,"riya",6.67,False]
l1.append(0.09)

# %%
l1
# Out:
# [2, 'riya', 6.67, False, 0.09]

# %%
l1.pop()
# Out:
# False

# %%
l1
# Out:
# [2, 'riya', 6.67]

# %%
l[3][0:2]
# Out:
# 'su'

# %%
s=str(l[4])

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, True]

# %%
s[0:2]
# Out:
# 'Tr'

# %%
l1.insert(2,8)

# %%
l1
# Out:
# [2, 'riya', 8, 8, 6.67]

# %%
l1.pop()
# Out:
# 8

# %%
l1
# Out:
# [2, 'riya']

# %%
l1
# Out:
# [2, 'riya']

# %%
name=input("enter name")
# Out:
# enter namekritika

# %%
print(name)
# Out:
# kritika

# %%
x=19
y=str(x)
print(y)
# Out:
# 19

# %%
x="3.45"
y=float(x)
print(y)
# Out:
# 3.45

# %%
x=(1,2,3)
y=list(x)
print(y)
# Out:
# [1, 2, 3]

# %%
z=3
w=str(z)
print(w)
# Out:
# 3

# %%
w
# Out:
# '3'
