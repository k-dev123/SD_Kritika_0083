# %% [markdown]
# <a href="https://colab.research.google.com/github/k-dev123/SD_Kritika_0083/blob/main/function_day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sum(a,b):
  x=a+b
  return x
sum(1,2)
# Out:
# 3

# %%
def test1():
  return("this is my first function ")

# %%
test1()+"sudh"
# Out:
# 'this is my first function sudh'

# %%
def test3():
  return "sudh",23,345.67,[1,2,3,3]
test3()
# Out:
# ('sudh', 23, 345.67, [1, 2, 3, 3])

# %%
a,b,c,d=test3()

# %%
test3()
# Out:
# ('sudh', 23, 345.67, [1, 2, 3, 3])

# %%
a
# Out:
# 'sudh'

# %%
b
# Out:
# 23

# %%
c
# Out:
# 345.67

# %%
d
# Out:
# [1, 2, 3, 3]

# %%
def test4():
  a=4+5/6
  return a
test4()
# Out:
# 4.833333333333333

# %%
def test5(a,b,c):
  d=a+b/c
  return d
test5(a,b,c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_725/1657875155.py in <cell line: 0>()
#       2   d=a+b/c
#       3   return d
# ----> 4 test5(a,b,c)
#
# /tmp/ipykernel_725/1657875155.py in test5(a, b, c)
#       1 def test5(a,b,c):
# ----> 2   d=a+b/c
#       3   return d
#       4 test5(a,b,c)
#
# TypeError: can only concatenate str (not "float") to str

# %%
def test5(a,b,c):
  d=a+b/c
  return d
test5(1,3,7)
# Out:
# 1.4285714285714286

# %%
def test5(a,b,c):
  d=a+b/c
  return d
a=float(input("enter any no "))
b=int(input("enter any no "))
c=int(input("enter any no "))
test5(a,b,c)
# Out:
# enter any no 3
# enter any no 4
# enter any no 5
# 3.8

# %%
def test6(a,b):
  c=a+b
  return c
test6("sudh","kumar")
# Out:
# 'sudhkumar'

# %%
def test6(a,b):
  c=a+b
  return c
a=eval(input("input enter tuple"))
b=eval(input("enter tuple"))
test6(a,b)
# Out:
# input enter tuple(4,5,6)
# enter tuple(4,56,7)
# (4, 5, 6, 4, 56, 7)

# %%
def test6(a,b):
  c=a+b
  return c
a=eval(input("input enter tuple"))
b=eval(input("enter tuple"))
test6(a,b)
# Out:
# input enter tuple[2,34,5]
# enter tuple[3,57,8]
# [2, 34, 5, 3, 57, 8]

# %%
def test7(*args):
  return args

# %%
type(test7())
# Out:
# tuple

# %%
test7(1,3,6)
# Out:
# (1, 3, 6)

# %%
def test7(*args):
  return args+(1,2,3,5)

# %%
test7()
# Out:
# (1, 2, 3, 5)

# %%
def test7(*kwargs):
  return kwargs+[1,2,3,4]

# %%
test7(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_725/3440988906.py in <cell line: 0>()
# ----> 1 test7(1,2,3)
#
# /tmp/ipykernel_725/3164017078.py in test7(*kwargs)
#       1 def test7(*kwargs):
# ----> 2   return kwargs+[1,2,3,4]
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
test7(1,2,3,"sudh","kumar",[1,2,3,5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_725/2551969452.py in <cell line: 0>()
# ----> 1 test7(1,2,3,"sudh","kumar",[1,2,3,5])
#
# /tmp/ipykernel_725/3164017078.py in test7(*kwargs)
#       1 def test7(*kwargs):
# ----> 2   return kwargs+[1,2,3,4]
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
def test8(*sudh):
  return sudh
test8(1)
# Out:
# (1,)

# %%
def test9(*args,a):
  return args,a
test9(1,2,3,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_725/249379435.py in <cell line: 0>()
#       1 def test9(*args,a):
#       2   return args,a
# ----> 3 test9(1,2,3,5)
#
# TypeError: test9() missing 1 required keyword-only argument: 'a'

# %%
def test10(c,d,a=0,b=1):
  return a,b,c,d

# %%
test10()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_725/4112227926.py in <cell line: 0>()
# ----> 1 test10()
#
# TypeError: test10() missing 2 required positional arguments: 'c' and 'd'

# %%
test10(3,4)
# Out:
# (0, 1, 3, 4)

# %%
test10(2,5,a=3445)
# Out:
# (3445, 1, 2, 5)

# %%
def test10(**kwargs):
  return kwargs
test10()
# Out:
# {}

# %%
def test10(**kwargs):
  return kwargs
test10()
# Out:
# {}

# %%
test10(a=[1.9,355],b="sudh",c=234.6)
# Out:
# {'a': [1.9, 355], 'b': 'sudh', 'c': 234.6}

# %%
def cal(n,n1,o):
    if o=="+":
      c=n+n1
      return c
    elif o=="-":
      c=n-n1
      return c
    elif o=="*":
      return n*n1
    elif o=="/":
      return n/n1
    else:
      return "error"
n=float(input("enter any no"))
n1=float(input("enter any no"))
o=input("enter operator")
cal(n,n1,o)
# Out:
# enter any no6
# enter any no8
# enter operator*
# 48.0

# %%
def deposit():
  pin = int(input("Enter PIN: "))
  if pin != customer["PIN"]:
    print("Invalid PIN")
  else:
    money=int(input("Enter amount to be deposited: "))
    customer["Amount"] = customer["Amount"] + money
def withdrawal():
  pin = int(input("Enter PIN: "))
  if pin != customer["PIN"]:
    print("Invalid PIN")
  else:
    money=int(input("Enter amount to be withdrawn: "))
    if customer["Amount"] < money:
      print("Not enough balance")
      return customer['Amount']
    else:
      customer["Amount"] = customer["Amount"] - money
      return customer["Amount"]
def amount():
  print(customer["Amount"])

def pin_change():
  pin = int(input("Enter PIN: "))
  if pin != customer["PIN"]:
    print("Invalid PIN")
  else:
    npin = int(input("Enter new PIN: "))
    n2pin = int(input("Confirm PIN: "))
    if npin != n2pin:
      print("Not same")
    else:
      print("PIN changed succesfully")

customer = {"Card number" : 1234 , "PIN" : 789 , "Amount" : 4500 }
cnum = int(input("Enter Card number: "))
if cnum != customer["Card number"]:
  print("Invalid Card Number")
else:
  p = 1
  while p==1:
    service = int(input("Services :\n 1-DEPOSIT \n 2-WITHDRAWAL \n 3-PIN CHANGE \n 4-AMOUNT CHECK \n 5-EXIT \n Enter Service: "))
    if service == 1:
      deposit()
    elif service == 2:
      print("new amount :" ,withdrawal())
    elif service == 3:
      pin_change()
    elif service == 4:
      amount()
    elif service == 5:
      p=0
      p
# Out:
# enter card no. 2344
# select any of the following services: 1,2,3,4
# enter any of the services 2
# enter amount45000
# enter ur pin no.456887
# failed
